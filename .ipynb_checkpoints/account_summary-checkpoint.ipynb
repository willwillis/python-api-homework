# %%
import os
import plaid
import requests
import datetime
import json
import pandas as pd
# %matplotlib inline

# %%
def pretty_print_response(response):
  print(json.dumps(response, indent=4, sort_keys=True))

# %%
PLAID_CLIENT_ID = os.getenv('PLAID_CLIENT_ID')
PLAID_SBX_SECRET_KEY = os.getenv('PLAID_SBX_SECRET_KEY')
PLAID_PUBLIC_KEY = os.getenv('PLAID_PUBLIC_KEY')
PLAID_ENV = os.getenv('PLAID_ENV', 'sandbox')
PLAID_PRODUCTS = os.getenv('PLAID_PRODUCTS', 'transactions')

# Oops, keys will forever be in repo history 
# print(PLAID_CLIENT_ID,PLAID_SBX_SECRET_KEY,PLAID_PUBLIC_KEY)

# %% [markdown]
# # Plaid Access Token
#
# In this section, you will use the plaid-python api to generate the correct authentication tokens to access data in the free developer Sandbox. This mimics how you might connect to your own account or a customer account, but due to privacy issues, this homework will only require connecting to and analyzing the fake data from the developer sandbox that Plaid provides.
#
# Complete the following steps to generate an access token:
# 1. Create a client to connect to paid
# 2. Use the client to generate a public token and request the following items:
# ['transactions', 'income', 'assets']
# 3. Exchange the public token for an access token
# 4. Test the access token by requesting and printing the available test accounts

# %% [markdown]
# ### 1. Create a client to connect to plaid

# %%
client = plaid.Client(client_id=PLAID_CLIENT_ID, secret=PLAID_SBX_SECRET_KEY, public_key=PLAID_PUBLIC_KEY, environment='sandbox')
print(client)
# Out:
# <plaid.client.Client object at 0x0000021EC4D27940>

# %% [markdown]
# ### 2. Generate a public token

# %%
# YOUR CODE HERE
INSTITUTION_ID = "ins_109508"

# Create public token to be exchanged for institution access token
create_tkn_response = client.Sandbox.public_token.create(INSTITUTION_ID, ['transactions','income','assets'])

# %% [markdown]
# ### 3. Exchange the public token for an access token

# %%
# Exchange public token for access token
exchange_response = client.Item.public_token.exchange(create_tkn_response['public_token'])
# Store access token as variable
access_token = exchange_response['access_token']

print(access_token)
# Out:
# access-sandbox-e4a72b4e-f3b0-4bc8-b2b4-894cd781beec

# %% [markdown]
# ### 4. Fetch Accounts

# %%
client.Accounts.get(access_token)
# Out:
# {'accounts': [{'account_id': '687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG',
#    'balances': {'available': 100,
#     'current': 110,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '0000',
#    'name': 'Plaid Checking',
#    'official_name': 'Plaid Gold Standard 0% Interest Checking',
#    'subtype': 'checking',
#    'type': 'depository'},
#   {'account_id': 'X59xVNo1zbIdJyRJyPvDiP4gq98v6eudQkwr9',
#    'balances': {'available': 200,
#     'current': 210,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '1111',
#    'name': 'Plaid Saving',
#    'official_name': 'Plaid Silver Standard 0.1% Interest Saving',
#    'subtype': 'savings',
#    'type': 'depository'},
#   {'account_id': 'D5vJzroRxnIxvy3vy7MztW6ej9gLvbUv1NKrZ',
#    'balances': {'available': None,
#     'current': 1000,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '2222',
#    'name': 'Plaid CD',
#    'official_name': 'Plaid Bronze Standard 0.2% Interest CD',
#    'subtype': 'cd',
#    'type': 'depository'},
#   {'account_id': 'V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl',
#    'balances': {'available': None,
#     'current': 410,
#     'iso_currency_code': 'USD',
#     'limit': 2000,
#     'unofficial_currency_code': None},
#    'mask': '3333',
#    'name': 'Plaid Credit Card',
#    'official_name': 'Plaid Diamond 12.5% APR Interest Credit Card',
#    'subtype': 'credit card',
#    'type': 'credit'},
#   {'account_id': 'wjovXz3AgRigMNwMNbkJtDxbP84pK9crGzBaK',
#    'balances': {'available': 43200,
#     'current': 43200,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '4444',
#    'name': 'Plaid Money Market',
#    'official_name': 'Plaid Platinum Standard 1.85% Interest Money Market',
#    'subtype': 'money market',
#    'type': 'depository'},
#   {'account_id': '5gjkMw7xLnhlMx5MxXrDCKedZzoAqMcZvXqEL',
#    'balances': {'available': None,
#     'current': 320.76,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '5555',
#    'name': 'Plaid IRA',
#    'official_name': None,
#    'subtype': 'ira',
#    'type': 'investment'},
#   {'account_id': 'J5mJNGka1wIxNXENX1AKtZrjXzD5A6cdAXVGW',
#    'balances': {'available': None,
#     'current': 23631.9805,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '6666',
#    'name': 'Plaid 401k',
#    'official_name': None,
#    'subtype': '401k',
#    'type': 'investment'},
#   {'account_id': 'kq4vQewbJMFAkzwkzLoPuwqGmge9Q1sW97y34',
#    'balances': {'available': None,
#     'current': 65262,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '7777',
#    'name': 'Plaid Student Loan',
#    'official_name': None,
#    'subtype': 'student',
#    'type': 'loan'}],
#  'item': {'available_products': ['auth',
#    'balance',
#    'credit_details',
#    'identity',
#    'investments',
#    'liabilities'],
#   'billed_products': ['assets', 'income', 'transactions'],
#   'error': None,
#   'institution_id': 'ins_109508',
#   'item_id': '687pbwXmonfP9Nn9NRzEIDxnq9nnDetgqdj3P',
#   'webhook': ''},
#  'request_id': 'LTzN1sHb1PH2N9E'}

# %% [markdown]
# ---

# %% [markdown]
# # Account Transactions with Plaid
#
# In this section, you will use the Plaid Python SDK to connect to the Developer Sandbox account and grab a list of transactions. You will need to complete the following steps:
#
#
# 1. Use the access token to fetch the transactions for the last 90 days
# 2. Print the categories for each transaction type
# 3. Create a new DataFrame using the following fields from the JSON transaction data: `date, name, amount, category`. (For categories with more than one label, just use the first category label in the list)
# 4. Convert the data types to the appropriate types (i.e. datetimeindex for the date and float for the amount)

# %% [markdown]
# ### 1. Fetch the Transactions for the last 90 days

# %%
# Get transactions for institution for specific date range
start_date = '{:%Y-%m-%d}'.format(datetime.datetime.now() + datetime.timedelta(-90))
end_date = '{:%Y-%m-%d}'.format(datetime.datetime.now())

# Get transactions for date range
transaction_response = client.Transactions.get(access_token,start_date,end_date)

# Print JSON output
transactions_list = json.dumps(transaction_response['transactions'],indent=4, sort_keys=True)
print(transactions_list)
# Out:
# [
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 500,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2019-08-29",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Tectra Inc",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "9AZJMvkVGRfn5d95dGmbFVDy6BPvkdiRroXe1",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 2078.5,
#         "category": [
#             "Payment"
#         ],
#         "category_id": "16000000",
#         "date": "2019-08-28",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "AUTOMATIC PAYMENT - THANK",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "687pbwXmonfP9Nn9NRzEIDx7PozmeZug6QVaa",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 500,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2019-08-28",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "KFC",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "R59qyeBVRwI64gw4gekjtEzjD8kA7guR9NmxL",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 500,
#         "category": [
#             "Shops",
#             "Sporting Goods"
#         ],
#         "category_id": "19046000",
#         "date": "2019-08-28",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Madison Bicycle Shop",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "vPkvWrB5pgiXJLnJLrQMCzXMmy4vWecWpb9Gd",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "X59xVNo1zbIdJyRJyPvDiP4gq98v6eudQkwr9",
#         "account_owner": null,
#         "amount": 25,
#         "category": [
#             "Payment",
#             "Credit Card"
#         ],
#         "category_id": "16001000",
#         "date": "2019-08-19",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CREDIT CARD 3333 PAYMENT *//",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "bJqZzap38Du3kwjkwrJNieBZpm9JzVtVlnM9k",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": 5.4,
#         "category": [
#             "Travel",
#             "Car Service",
#             "Ride Share"
#         ],
#         "category_id": "22006001",
#         "date": "2019-08-19",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber 063015 SF**POOL**",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "8kQgjx6wWJHekxokxM51uk6JBgKpvecwn7kQo",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "wjovXz3AgRigMNwMNbkJtDxbP84pK9crGzBaK",
#         "account_owner": null,
#         "amount": 5850,
#         "category": [
#             "Transfer",
#             "Debit"
#         ],
#         "category_id": "21006000",
#         "date": "2019-08-18",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "ACH Electronic CreditGUSTO PAY 123456",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": "ACH",
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "V59ByXp1lZIjpE7pE6kVCGnkewzgM7cWaQ35W",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "D5vJzroRxnIxvy3vy7MztW6ej9gLvbUv1NKrZ",
#         "account_owner": null,
#         "amount": 1000,
#         "category": [
#             "Transfer",
#             "Deposit"
#         ],
#         "category_id": "21007000",
#         "date": "2019-08-18",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CD DEPOSIT .INITIAL.",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "yepwWad3AkSXRl1RlDAeC3Rz1BpqKWcyGP71d",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 78.5,
#         "category": [
#             "Recreation",
#             "Gyms and Fitness Centers"
#         ],
#         "category_id": "17018000",
#         "date": "2019-08-17",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Touchstone Climbing",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "X59xVNo1zbIdJyRJyPvDiP4gzVA9wptdQkwMp",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": -500,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2019-08-17",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "E56JBz7NaVInoWQoWLM1FmnBN4gEqwfXy8pAq",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": 12,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2019-08-16",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": "3322"
#         },
#         "name": "McDonald's",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "W593yoJ8KXIEDjqDjbmVuVLAZJwl1dilR3JNG",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": 4.33,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Coffee Shop"
#         ],
#         "category_id": "13005043",
#         "date": "2019-08-16",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Starbucks",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "ARmJkl1QqwCnpoXpomMkFlJwmxaVyEu18LnVX",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": 89.4,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2019-08-15",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "SparkFun",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "G5mJxGw3jnIx1Db1D8p4tMladnyvrqI1aKzNl",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "X59xVNo1zbIdJyRJyPvDiP4gq98v6eudQkwr9",
#         "account_owner": null,
#         "amount": -4.22,
#         "category": [
#             "Transfer",
#             "Credit"
#         ],
#         "category_id": "21005000",
#         "date": "2019-08-14",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "INTRST PYMNT",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "mkPvXeJLrMHDxPAxP4wJSm7DewKxWVfLEeVKm",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 500,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2019-08-04",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "D5vJzroRxnIxvy3vy7MztW6eMa19lKhv1NKlz",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": 6.33,
#         "category": [
#             "Travel",
#             "Car Service",
#             "Ride Share"
#         ],
#         "category_id": "22006001",
#         "date": "2019-08-02",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber 072515 SF**POOL**",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "nzjvQX4pBRu69nR9nQ7ateAjwz7gpDt6o9L7o",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 500,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2019-07-30",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Tectra Inc",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "N59JjeqwA8IaLAMLAVJyuMdwrR5dr4HWJrgQR",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 2078.5,
#         "category": [
#             "Payment"
#         ],
#         "category_id": "16000000",
#         "date": "2019-07-29",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "AUTOMATIC PAYMENT - THANK",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "4oP1k36vMnsQ6wk6w7KDfbJGjLWJjzFdygZLj",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 500,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2019-07-29",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "KFC",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "a5lQrEkdo6IJE9ZE9og6cA4mLwJ4LWF7mRzDj",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 500,
#         "category": [
#             "Shops",
#             "Sporting Goods"
#         ],
#         "category_id": "19046000",
#         "date": "2019-07-29",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Madison Bicycle Shop",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "d5r13lgdGMIw53d53b9ZulZ1KJwZKPtZ1PmR5",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "X59xVNo1zbIdJyRJyPvDiP4gq98v6eudQkwr9",
#         "account_owner": null,
#         "amount": 25,
#         "category": [
#             "Payment",
#             "Credit Card"
#         ],
#         "category_id": "16001000",
#         "date": "2019-07-20",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CREDIT CARD 3333 PAYMENT *//",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "d5r13lgdGMIw53d53b9ZulZ1KJwZKPtZ1Pmen",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": 5.4,
#         "category": [
#             "Travel",
#             "Car Service",
#             "Ride Share"
#         ],
#         "category_id": "22006001",
#         "date": "2019-07-20",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber 063015 SF**POOL**",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "3pNMXWPBQnfravPavnqATlegWNQeWEtqywBeR",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "wjovXz3AgRigMNwMNbkJtDxbP84pK9crGzBaK",
#         "account_owner": null,
#         "amount": 5850,
#         "category": [
#             "Transfer",
#             "Debit"
#         ],
#         "category_id": "21006000",
#         "date": "2019-07-19",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "ACH Electronic CreditGUSTO PAY 123456",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": "ACH",
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "vPkvWrB5pgiXJLnJLrQMCzXmV53XVWiWQoEZx",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "D5vJzroRxnIxvy3vy7MztW6ej9gLvbUv1NKrZ",
#         "account_owner": null,
#         "amount": 1000,
#         "category": [
#             "Transfer",
#             "Deposit"
#         ],
#         "category_id": "21007000",
#         "date": "2019-07-19",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CD DEPOSIT .INITIAL.",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "Q5klGezV9pIDEwZEwJ6RSaw7RmDwRjTpQkJEa",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 78.5,
#         "category": [
#             "Recreation",
#             "Gyms and Fitness Centers"
#         ],
#         "category_id": "17018000",
#         "date": "2019-07-18",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Touchstone Climbing",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "x7JvWdxBEDIvM1lM1578u7PqlrWPlDTna9qeW",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": -500,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2019-07-18",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "B6mJKqwlrLiq63J631bnCXvlzZLvzMCwo7QN8",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": 12,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2019-07-17",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": "3322"
#         },
#         "name": "McDonald's",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "rdZvWLqRj7FoPv4PvX6RuP1Z4NJ14gflRynVV",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": 4.33,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Coffee Shop"
#         ],
#         "category_id": "13005043",
#         "date": "2019-07-17",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Starbucks",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "zQbvw4JMnlTdJ3vJ3g5eiPr7v3lrvnfobEz1W",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": 89.4,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2019-07-16",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "SparkFun",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "K5mJNeRapAILNJeNJ7ogua7QRw57RxTVX6LaL",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "X59xVNo1zbIdJyRJyPvDiP4gq98v6eudQkwr9",
#         "account_owner": null,
#         "amount": -4.22,
#         "category": [
#             "Transfer",
#             "Credit"
#         ],
#         "category_id": "21005000",
#         "date": "2019-07-15",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "INTRST PYMNT",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "x7JvWdxBEDIvM1lM1578u7PqlrWPlDTna9qve",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 500,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2019-07-05",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "3pNMXWPBQnfravPavnqATlegWNQeWEtqywBE5",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": 6.33,
#         "category": [
#             "Travel",
#             "Car Service",
#             "Ride Share"
#         ],
#         "category_id": "22006001",
#         "date": "2019-07-03",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber 072515 SF**POOL**",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "qxQv1mlXNJi4Pk8Pkj75uVon8wpo8BfdKJZ1n",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 500,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2019-06-30",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Tectra Inc",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "B6mJKqwlrLiq63J631bnCXvlzZLvzMCwo7Qga",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 2078.5,
#         "category": [
#             "Payment"
#         ],
#         "category_id": "16000000",
#         "date": "2019-06-29",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "AUTOMATIC PAYMENT - THANK",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "zQbvw4JMnlTdJ3vJ3g5eiPr7v3lrvnfobEzQe",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 500,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2019-06-29",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "KFC",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "rdZvWLqRj7FoPv4PvX6RuP1Z4NJ14gflRyn1p",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 500,
#         "category": [
#             "Shops",
#             "Sporting Goods"
#         ],
#         "category_id": "19046000",
#         "date": "2019-06-29",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Madison Bicycle Shop",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "K5mJNeRapAILNJeNJ7ogua7QRw57RxTVX6L1n",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "X59xVNo1zbIdJyRJyPvDiP4gq98v6eudQkwr9",
#         "account_owner": null,
#         "amount": 25,
#         "category": [
#             "Payment",
#             "Credit Card"
#         ],
#         "category_id": "16001000",
#         "date": "2019-06-20",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CREDIT CARD 3333 PAYMENT *//",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "3pNMXWPBQnfravPavnqATlegWNQeWEtqywB3R",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": 5.4,
#         "category": [
#             "Travel",
#             "Car Service",
#             "Ride Share"
#         ],
#         "category_id": "22006001",
#         "date": "2019-06-20",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber 063015 SF**POOL**",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "lKN6QX7WqmImboQboRVatwA8QKmAQ1IZ3Lkej",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "wjovXz3AgRigMNwMNbkJtDxbP84pK9crGzBaK",
#         "account_owner": null,
#         "amount": 5850,
#         "category": [
#             "Transfer",
#             "Debit"
#         ],
#         "category_id": "21006000",
#         "date": "2019-06-19",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "ACH Electronic CreditGUSTO PAY 123456",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": "ACH",
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "9AZJMvkVGRfn5d95dGmbFVD6GzNDGkfRNl59G",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "D5vJzroRxnIxvy3vy7MztW6ej9gLvbUv1NKrZ",
#         "account_owner": null,
#         "amount": 1000,
#         "category": [
#             "Transfer",
#             "Deposit"
#         ],
#         "category_id": "21007000",
#         "date": "2019-06-19",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CD DEPOSIT .INITIAL.",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "e5zLxq6abMIqMwQMwADZCGAZQMqAQXTLZMz17",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 78.5,
#         "category": [
#             "Recreation",
#             "Gyms and Fitness Centers"
#         ],
#         "category_id": "17018000",
#         "date": "2019-06-18",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Touchstone Climbing",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "qxQv1mlXNJi4Pk8Pkj75uVon8wpo8BfdKJZRV",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": -500,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2019-06-18",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "kq4vQewbJMFAkzwkzLoPuwqNnoAqn4IW5xXeZ",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": 12,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2019-06-17",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": "3322"
#         },
#         "name": "McDonald's",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "5gjkMw7xLnhlMx5MxXrDCKe13lQe3BFZrxWWk",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": 4.33,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Coffee Shop"
#         ],
#         "category_id": "13005043",
#         "date": "2019-06-17",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Starbucks",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "J5mJNGka1wIxNXENX1AKtZrPvbLrv3Cd8b997",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": 89.4,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2019-06-16",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "SparkFun",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "wjovXz3AgRigMNwMNbkJtDxzwr3xwnFrXg55B",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "X59xVNo1zbIdJyRJyPvDiP4gq98v6eudQkwr9",
#         "account_owner": null,
#         "amount": -4.22,
#         "category": [
#             "Transfer",
#             "Credit"
#         ],
#         "category_id": "21005000",
#         "date": "2019-06-15",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "INTRST PYMNT",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "B6mJKqwlrLiq63J631bnCXvlzZLvzMCwo7Qn8",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 500,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2019-06-05",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "lKN6QX7WqmImboQboRVatwA8QKmAQ1IZ3LkRE",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "687pbwXmonfP9Nn9NRzEIDx7ymWwbLcg6QVqG",
#         "account_owner": null,
#         "amount": 6.33,
#         "category": [
#             "Travel",
#             "Car Service",
#             "Ride Share"
#         ],
#         "category_id": "22006001",
#         "date": "2019-06-03",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber 072515 SF**POOL**",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "V59ByXp1lZIjpE7pE6kVCGneDZ8nDMTWM6wwj",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "V59ByXp1lZIjpE7pE6kVCGnkJgQKXEsWaQ3vl",
#         "account_owner": null,
#         "amount": 500,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2019-05-31",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Tectra Inc",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_id": "kq4vQewbJMFAkzwkzLoPuwqNnoAqn4IW5xXoJ",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     }
# ]

# %% [markdown]
# ### 2. Print the categories for each transaction

# %%
transactions = transaction_response['transactions']
all_categories = []
for tran in transactions:
    category = tran['category'][0]
    all_categories.append(category)
    print(category)
# Out:
# Food and Drink
# Payment
# Food and Drink
# Shops
# Payment
# Travel
# Transfer
# Transfer
# Recreation
# Travel
# Food and Drink
# Food and Drink
# Food and Drink
# Transfer
# Travel
# Travel
# Food and Drink
# Payment
# Food and Drink
# Shops
# Payment
# Travel
# Transfer
# Transfer
# Recreation
# Travel
# Food and Drink
# Food and Drink
# Food and Drink
# Transfer
# Travel
# Travel
# Food and Drink
# Payment
# Food and Drink
# Shops
# Payment
# Travel
# Transfer
# Transfer
# Recreation
# Travel
# Food and Drink
# Food and Drink
# Food and Drink
# Transfer
# Travel
# Travel
# Food and Drink

# %% [markdown]
# ### 3. Create a new DataFrame using the following fields from the JSON transaction data: date, name, amount, category.
#
# (For categories with more than one label, just use the first category label in the list)

# %%
transactions = transaction_response['transactions']

all_dates = []
all_seller_name = []
all_amount = []
all_categories = []

for tran in transactions:
    category = tran['category'][0]
    all_categories.append(category)
    all_dates.append(tran['date'])
    all_seller_name.append(tran['name'])
    all_amount.append(tran['amount'])

for i in range(len(all_dates)):
    print(f"{all_dates[i]} {all_seller_name[i]} \t ${all_amount[i]} Cat: {all_categories[i]}")

df = pd.DataFrame(list(zip(all_dates,all_seller_name,all_amount,all_categories)), 
                columns =['Date','Seller','Amount','Category'])
df.head()
# Out:
# 2019-08-29 Tectra Inc 	 $500 Cat: Food and Drink
# 2019-08-28 AUTOMATIC PAYMENT - THANK 	 $2078.5 Cat: Payment
# 2019-08-28 KFC 	 $500 Cat: Food and Drink
# 2019-08-28 Madison Bicycle Shop 	 $500 Cat: Shops
# 2019-08-19 CREDIT CARD 3333 PAYMENT *// 	 $25 Cat: Payment
# 2019-08-19 Uber 063015 SF**POOL** 	 $5.4 Cat: Travel
# 2019-08-18 ACH Electronic CreditGUSTO PAY 123456 	 $5850 Cat: Transfer
# 2019-08-18 CD DEPOSIT .INITIAL. 	 $1000 Cat: Transfer
# 2019-08-17 Touchstone Climbing 	 $78.5 Cat: Recreation
# 2019-08-17 United Airlines 	 $-500 Cat: Travel
# 2019-08-16 McDonald's 	 $12 Cat: Food and Drink
# 2019-08-16 Starbucks 	 $4.33 Cat: Food and Drink
# 2019-08-15 SparkFun 	 $89.4 Cat: Food and Drink
# 2019-08-14 INTRST PYMNT 	 $-4.22 Cat: Transfer
# 2019-08-04 United Airlines 	 $500 Cat: Travel
# 2019-08-02 Uber 072515 SF**POOL** 	 $6.33 Cat: Travel
# 2019-07-30 Tectra Inc 	 $500 Cat: Food and Drink
# 2019-07-29 AUTOMATIC PAYMENT - THANK 	 $2078.5 Cat: Payment
# 2019-07-29 KFC 	 $500 Cat: Food and Drink
# 2019-07-29 Madison Bicycle Shop 	 $500 Cat: Shops
# 2019-07-20 CREDIT CARD 3333 PAYMENT *// 	 $25 Cat: Payment
# 2019-07-20 Uber 063015 SF**POOL** 	 $5.4 Cat: Travel
# 2019-07-19 ACH Electronic CreditGUSTO PAY 123456 	 $5850 Cat: Transfer
# 2019-07-19 CD DEPOSIT .INITIAL. 	 $1000 Cat: Transfer
# 2019-07-18 Touchstone Climbing 	 $78.5 Cat: Recreation
# 2019-07-18 United Airlines 	 $-500 Cat: Travel
# 2019-07-17 McDonald's 	 $12 Cat: Food and Drink
# 2019-07-17 Starbucks 	 $4.33 Cat: Food and Drink
# 2019-07-16 SparkFun 	 $89.4 Cat: Food and Drink
# 2019-07-15 INTRST PYMNT 	 $-4.22 Cat: Transfer
# 2019-07-05 United Airlines 	 $500 Cat: Travel
# 2019-07-03 Uber 072515 SF**POOL** 	 $6.33 Cat: Travel
# 2019-06-30 Tectra Inc 	 $500 Cat: Food and Drink
# 2019-06-29 AUTOMATIC PAYMENT - THANK 	 $2078.5 Cat: Payment
# 2019-06-29 KFC 	 $500 Cat: Food and Drink
# 2019-06-29 Madison Bicycle Shop 	 $500 Cat: Shops
# 2019-06-20 CREDIT CARD 3333 PAYMENT *// 	 $25 Cat: Payment
# 2019-06-20 Uber 063015 SF**POOL** 	 $5.4 Cat: Travel
# 2019-06-19 ACH Electronic CreditGUSTO PAY 123456 	 $5850 Cat: Transfer
# 2019-06-19 CD DEPOSIT .INITIAL. 	 $1000 Cat: Transfer
# 2019-06-18 Touchstone Climbing 	 $78.5 Cat: Recreation
# 2019-06-18 United Airlines 	 $-500 Cat: Travel
# 2019-06-17 McDonald's 	 $12 Cat: Food and Drink
# 2019-06-17 Starbucks 	 $4.33 Cat: Food and Drink
# 2019-06-16 SparkFun 	 $89.4 Cat: Food and Drink
# 2019-06-15 INTRST PYMNT 	 $-4.22 Cat: Transfer
# 2019-06-05 United Airlines 	 $500 Cat: Travel
# 2019-06-03 Uber 072515 SF**POOL** 	 $6.33 Cat: Travel
# 2019-05-31 Tectra Inc 	 $500 Cat: Food and Drink
#          Date                        Seller  Amount        Category
# 0  2019-08-29                    Tectra Inc   500.0  Food and Drink
# 1  2019-08-28     AUTOMATIC PAYMENT - THANK  2078.5         Payment
# 2  2019-08-28                           KFC   500.0  Food and Drink
# 3  2019-08-28          Madison Bicycle Shop   500.0           Shops
# 4  2019-08-19  CREDIT CARD 3333 PAYMENT *//    25.0         Payment

# %% [markdown]
# ### 4. Convert the data types to the appropriate types
#
# (i.e. datetimeindex for the date and float for the amount)

# %%
df['Seller'].astype('str')
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)
print(df.dtypes)
df.head()
# Out:
# Seller       object
# Amount      float64
# Category     object
# dtype: object
#                                   Seller  Amount        Category
# Date
# 2019-08-28     AUTOMATIC PAYMENT - THANK  2078.5         Payment
# 2019-08-28                           KFC   500.0  Food and Drink
# 2019-08-28          Madison Bicycle Shop   500.0           Shops
# 2019-08-19  CREDIT CARD 3333 PAYMENT *//    25.0         Payment
# 2019-08-19        Uber 063015 SF**POOL**     5.4          Travel

# %% [markdown]
# ---

# %% [markdown]
# # Income Analysis with Plaid
#
# In this section, you will use the Plaid Sandbox to complete the following:
# 1. Determine the previous year's gross income and print the results
# 2. Determine the current monthly income and print the results
# 3. Determine the projected yearly income and print the results

# %%
client.Accounts.get(access_token)
resp = client.Income.get(access_token)
last_year_gross_income = resp['income']['last_year_income_before_tax']
monthly_income = resp['income']['income_streams'][0]['monthly_income']
projected_yearly_income = monthly_income * 12

print(f"1. Previous Year's Gross Income: ${last_year_gross_income:,}")
print(f"2. Current Monthly Income: ${monthly_income}")
print(f"3. Projected Yearly Income: ${projected_yearly_income:,}")

# I'm so digging the fstring formats in python
# source: https://stackoverflow.com/questions/1823058/how-to-print-number-with-commas-as-thousands-separators
# Out:
# 1. Previous Year's Gross Income: $7,285
# 2. Current Monthly Income: $500
# 3. Projected Yearly Income: $6,000

# %% [markdown]
# ---

# %% [markdown]
# # Budget Analysis
# In this section, you will use the transactions DataFrame to analyze the customer's budget
#
# 1. Calculate the total spending per category and print the results (Hint: groupby or count transactions per category)
# 2. Generate a bar chart with the number of transactions for each category
# 3. Calulate the expenses per month
# 4. Plot the total expenses per month

# %% [markdown]
# ### Calculate the expenses per category

# %%
df_category_sum = df.filter(['Category','Amount'])
grouped = df_category_sum.groupby(['Category']).sum()
grouped.columns = ['Total Spending Per Category']
grouped.sort_values('Total Spending Per Category',ascending=False,inplace=True)
print(grouped)
#grouped.plot.bar(figsize=(15,8), title="Spending per Category")

grouped_count = df.filter(['Category','Amount']).groupby(['Category']).count()
grouped_count.columns = ['Transaction Count']
grouped_count.sort_values('Transaction Count',ascending=False,inplace=True)
grouped_count.plot.bar(figsize=(15,8), title="Transaction Counts Per Category")
# Out:
#                 Total Spending Per Category
# Category
# Transfer                           20537.34
# Payment                             6310.50
# Food and Drink                      3817.19
# Shops                               1500.00
# Recreation                           235.50
# Travel                                35.19

# %% [markdown]
# ### Calculate the expenses per month

# %%
df_amounts = df.filter(['Date','Amount'])
print(df_amounts.head())
pd.to_datetime(df_amounts,errors='ignore' )
print(df_amounts.dtypes)
#df_amounts.index.astype('datetime64')
#print(df_amounts.dtypes)
#month_grouped = df_amounts.groupby([df_amounts.index.month]).sum()
#month_grouped.head()
# month_grouped.head()
#df_category.dtypes()
# Out:
#          Date  Amount
# 0  2019-08-29   500.0
# 1  2019-08-28  2078.5
# 2  2019-08-28   500.0
# 3  2019-08-28   500.0
# 4  2019-08-19    25.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-e51c71a0f35d> in <module>
#       1 df_amounts = df.filter(['Date','Amount'])
#       2 print(df_amounts.head())
# ----> 3 pd.to_datetime(df_amounts,errors='ignore' )
#       4 print(df_amounts.dtypes)
#       5 #df_amounts.index.astype('datetime64')
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     779             result = arg._constructor(values, index=arg.index, name=arg.name)
#     780     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# --> 781         result = _assemble_from_unit_mappings(arg, errors, box, tz)
#     782     elif isinstance(arg, ABCIndexClass):
#     783         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _assemble_from_unit_mappings(arg, errors, box, tz)
#     875             "to assemble mappings requires at least that "
#     876             "[year, month, day] be specified: [{required}] "
# --> 877             "is missing".format(required=",".join(req))
#     878         )
#     879
#
# ValueError: to assemble mappings requires at least that [year, month, day] be specified: [day,month,year] is missing
